# %% [markdown]
# Rishikesan "Rishi" Ravichandran

# %%
from bs4 import BeautifulSoup 
import time 
import requests 
import re 
import os

# %% [markdown]
# <br>

# %% [markdown]
# Let us determine how URL changes when we change the page, and for this we will use our sorted URL by oldest items, "https://sfbay.craigslist.org/search/zip?sort=dateoldest#search=1~gallery~0~0". When we move between pages, the value after second tilde changes i.e 1\~gallery\~**page_number**\~0", as represented by'page_number' here changes.
#
# The variable associated with page change is 'search'. As seen here, "search=1\~gallery\~**page_number**\~0" However, it is good to note that this variable 'search' after the first variable 'sort' does not only change the page, but also other dropdown options like 'Gallery'/'Preview' etc. But, only after the second tilde, whatever number comes just after that will take us to that particular page.
#
# It is interesting to know that when we load the original URL "https://sfbay.craigslist.org/search/zip", it directly adds "#search=1\~gallery\~0\~0" to that URL, and when we add or change the sorting, a new variable is preceded by this i.e 'sort'.

# %%
def fetch_top_250_url():
    """
    Function to fetch top 250 URLS.
    """
    
    headers = {'User-agent': 'Mozilla/5.0'}
    
    #From our previous exploration, we know the URL that could help us get “free” section, ordered “newest” first.
    url = "https://sfbay.craigslist.org/search/zip?sort=date"
    
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #We'll find all the list item under the class='cl-results-page'
    results_list=soup.select('li',class_='cl-results-page')

    print("\n*** Function Output Start ****\n")
    print("A sample of listing items,\n\n",results_list[0:3])
    
    #From above, we can see that each listing is starting from second element in 'results_list'
    
    print(f"\n\nThe total number of listing items fetched at this time using the requests is {len(results_list[0:])}\n\n")
    
    #So we don't have to request page 2, page 3 etc., while exploration it showed only first 120 items on the website, 
    #with requests it is showing more than 300. Since, our objective is only to fetch top 250 items, we'll just use that. 
    
    #So let us run a loop for 1:251 to store the top 250 listed item's URL
    
    items_url = []
    for i in list(range(1,251)):
        items_url.append(results_list[i].select_one('a').get('href'))
    print("\n*** Function Output End ****\n")
    return items_url

top_250_urls=fetch_top_250_url()

print("The top 250 urls are shown below: \n\n")
top_250_urls
# Out:
# *** Function Output Start ****
#
# A sample of listing items,
#
#  [<li class="cl-static-hub-links">
# <div>see also</div>
# </li>, <li class="cl-static-search-result" title="Evenflo  PIVOT XPAND TRAVEL SYSTEM">
# <a href="https://sfbay.craigslist.org/sby/zip/d/campbell-evenflo-pivot-xpand-travel/7714053414.html">
# <div class="title">Evenflo  PIVOT XPAND TRAVEL SYSTEM</div>
# <div class="details">
# <div class="price">$0</div>
# <div class="location">
#                         campbell
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Treadmill">
# <a href="https://sfbay.craigslist.org/eby/zip/d/lafayette-treadmill/7715509943.html">
# <div class="title">Treadmill</div>
# <div class="details">
# <div class="price">$0</div>
# <div class="location">
#                         lafayette / orinda / moraga
#                     </div>
# </div>
# </a>
# </li>]
#
#
# The total number of listing items fetched at this time using the requests is 361
#
#
#
# *** Function Output End ****
#
# The top 250 urls are shown below:
# ['https://sfbay.craigslist.org/sby/zip/d/campbell-evenflo-pivot-xpand-travel/7714053414.html',
#  'https://sfbay.craigslist.org/eby/zip/d/lafayette-treadmill/7715509943.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-bath-light-bar-light/7715509713.html',
#  'https://sfbay.craigslist.org/nby/zip/d/sebastopol-vinyl-floor-tiles/7715509520.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-scooter-nanrobot/7715509412.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-two-guitar-stands/7715509163.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-binders/7715508675.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-delonghi-space-heater/7715508529.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-stuff-see-pics/7713265862.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-large-sicker-dog-bed-and-pad/7715507916.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-outdoor-candle-holder/7712855788.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-assorted-curtain-rods/7713944084.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-3drawer-cd-holder-storage/7714558929.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-queen-aerobed-air/7713089936.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-land-line-phone/7714559986.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-couch-sofa-free/7715507681.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-usb-camera/7714559809.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-acrylic-shelf/7714624891.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-assorted-phone-wires/7714688000.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-smart-cat-touchpad/7714689535.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-pc-mouse-2/7714690505.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ibm-electric-letter-font/7714743061.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-soap-holder/7714733644.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-under-bed-storage-bin-for/7715506453.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-link-wireless-router/7715506294.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-mini-fridge-pots-ice-trays/7715505539.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-shaped-glass-desk/7715505407.html',
#  'https://sfbay.craigslist.org/nby/zip/d/sebastopol-queen-size-comforter/7715505302.html',
#  'https://sfbay.craigslist.org/eby/zip/d/lafayette-free-art-deco-lamp/7715504693.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-epson-ink-cartridges/7715504408.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-square-glass-table-top/7715503848.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-metal-garden-bench/7715503792.html',
#  'https://sfbay.craigslist.org/nby/zip/d/larkspur-ecoreco-m5-s5-electric-scooters/7715503784.html',
#  'https://sfbay.craigslist.org/eby/zip/d/emeryville-free-bags-of-wood-kindling/7715503718.html',
#  'https://sfbay.craigslist.org/nby/zip/d/sausalito-various-free-things/7710584033.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-witch-hazel/7714206761.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fairfield-free-bedroom-set/7715500343.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-pallet/7715497408.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-baby-gate-inches/7715496150.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-cat-furniture/7715495862.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-humidifier-holmes/7713160483.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-costume-paint-and-fake/7713154629.html',
#  'https://sfbay.craigslist.org/nby/zip/d/cotati-coffee-table-and-two-end-tables/7715495491.html',
#  'https://sfbay.craigslist.org/nby/zip/d/mill-valley-infinity-kappa-speakers-pair/7715495119.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-bookshelf-vintage-wall/7715494220.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-led-retrofit-bulbs-for-pin-cfl/7715493932.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-beige-light-brown-carpet-scraps/7715493105.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-subaru-teeeter-speakers/7715493835.html',
#  'https://sfbay.craigslist.org/eby/zip/d/newark-scuba-gear/7715492561.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-carpet-with-flowery/7715491670.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-shaped-couch-blue/7715490338.html',
#  'https://sfbay.craigslist.org/scz/zip/d/capitola-queen-box-spring/7715490231.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-books-games/7713360347.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-ramon-real-leather-sofa-with/7708907086.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-new-free-collapsible-dish/7715488259.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-easter-decorations/7714763829.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-bamboo-charging-station/7715484285.html',
#  'https://sfbay.craigslist.org/nby/zip/d/windsor-free-counter-top/7712206329.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-garage-grade-free-folding-table/7715481682.html',
#  'https://sfbay.craigslist.org/nby/zip/d/windsor-free-counter-top/7710582593.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-chair-headboard-filing/7713900033.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-mountain-bikes/7715480286.html',
#  'https://sfbay.craigslist.org/eby/zip/d/union-city-used-37-tires/7711667389.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-chairs-blue-plastic-and/7715478238.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-samsung-galaxy-gear-vr-oculus/7715477246.html',
#  'https://sfbay.craigslist.org/eby/zip/d/richmond-glass-shower-doors/7715477067.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-tire-continential/7715474830.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-carlos-subaru-crosstrek-engine-free/7715474805.html',
#  'https://sfbay.craigslist.org/pen/zip/d/mountain-view-free-amazon-boxes/7715474218.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasanton-queen-anne-table-175/7715472948.html',
#  'https://sfbay.craigslist.org/nby/zip/d/sausalito-coffee-table-thick-cut-glass/7707133848.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-wall-art-free/7715472124.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-curb-alert-free-sandbags/7715471741.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-cherry-hardwood-surfer-table/7715471491.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasanton-entertainment-unit/7715471475.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-whiteboard/7715470701.html',
#  'https://sfbay.craigslist.org/eby/zip/d/richmond-large-sheet-of-tempered-glass/7715470479.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-box-spring-full-size/7715470127.html',
#  'https://sfbay.craigslist.org/nby/zip/d/vallejo-twin-quilt/7715468334.html',
#  'https://sfbay.craigslist.org/eby/zip/d/richmond-round-4-glass-for-table-top/7715468312.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-moving-boxes/7715467833.html',
#  'https://sfbay.craigslist.org/scz/zip/d/hollister-hollister-arborist-woodchips/7711183528.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-wooden-cabinet/7715466412.html',
#  'https://sfbay.craigslist.org/eby/zip/d/richmond-round-table-top-with-lazy-susan/7715466178.html',
#  'https://sfbay.craigslist.org/eby/zip/d/martinez-free-workbench-or-desk-plus/7715453823.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-modern-twin-bed/7715463536.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-panasonic-surround/7715461356.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-surplus-yogurt-eggnog-milk/7715460536.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-sandbags/7715459120.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-foot-corrugated/7713576351.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-ashton-drake-caught-in-the-act/7715458393.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-craps-table-for-free/7715458153.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-laskso-utility-fan/7715451702.html',
#  'https://sfbay.craigslist.org/pen/zip/d/los-altos-leather-couch-no-tears/7715451413.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-2013-highlander-rear-area-mat/7715450519.html',
#  'https://sfbay.craigslist.org/nby/zip/d/larkspur-vitamaster-triumph-treadmill/7711309600.html',
#  'https://sfbay.craigslist.org/eby/zip/d/martinez-free-storage-cabinet-plus-ill/7715449942.html',
#  'https://sfbay.craigslist.org/eby/zip/d/lafayette-free-desk-chair-with-arms/7715449570.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free/7714735168.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-construction-safety/7714717921.html',
#  'https://sfbay.craigslist.org/scz/zip/d/moss-landing-free-plastic-nursery-pots/7715448448.html',
#  'https://sfbay.craigslist.org/pen/zip/d/menlo-park-free-fig-tree/7715447828.html',
#  'https://sfbay.craigslist.org/eby/zip/d/martinez-free-mirror/7715447784.html',
#  'https://sfbay.craigslist.org/nby/zip/d/windsor-grape-gondola/7715447740.html',
#  'https://sfbay.craigslist.org/eby/zip/d/lafayette-free-desk-chair/7715447619.html',
#  'https://sfbay.craigslist.org/eby/zip/d/richmond-crutches/7715447614.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/free-bags-of-sand-construction/7712106559.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-free-lazy-boy-sectional-couch/7715444062.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/daly-city-free-walker/7715444053.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-free-kitchen-sink/7709526645.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-small-sofa/7715442405.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-file-cabinet-oak/7715440534.html',
#  'https://sfbay.craigslist.org/pen/zip/d/atherton-free-bucket-buddy-tool-holder/7715438964.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-wood-chips/7715436732.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-drawer-metal-filing-cabinet/7715434602.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-two-twin-box-spring/7715434405.html',
#  'https://sfbay.craigslist.org/eby/zip/d/livermore-free-landline-att-phones/7715432500.html',
#  'https://sfbay.craigslist.org/nby/zip/d/bolinas-free-working-record-player/7712443048.html',
#  'https://sfbay.craigslist.org/eby/zip/d/dublin-office-furniture-desks-hutch/7715427395.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-ceiling-lamp/7712855303.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-cpcu-commercial-insurance/7707638711.html',
#  'https://sfbay.craigslist.org/scz/zip/d/scotts-valley-free-king-size-bed/7715423737.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-tv-art-stand-like-new/7715423129.html',
#  'https://sfbay.craigslist.org/nby/zip/d/san-rafael-tv-40-samsung-free/7710945210.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-cabinet-on-wheels/7715421404.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-half-bag-of-ice/7715418706.html',
#  'https://sfbay.craigslist.org/nby/zip/d/healdsburg-free-tool-boxes-and-circular/7715416372.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-1978-toyota-celica-parts/7712891804.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ikea-sparsam-bulbs-brand/7715416308.html',
#  'https://sfbay.craigslist.org/eby/zip/d/castro-valley-free-concrete-decorative/7712229203.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-upright-piano/7710208630.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-office-desk/7710140691.html',
#  'https://sfbay.craigslist.org/eby/zip/d/walnut-creek-free-275-gallon-water-totes/7715414014.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-small-microwave/7715412792.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-working-fridge/7715411920.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-free-balloon-arch/7715407430.html',
#  'https://sfbay.craigslist.org/eby/zip/d/albany-drapes-heavy-duty/7715405474.html',
#  'https://sfbay.craigslist.org/eby/zip/d/moraga-tv-media-stand/7709936764.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-free-electronics/7714484558.html',
#  'https://sfbay.craigslist.org/sby/zip/d/santa-clara-honda-z50-flywheels-mini/7708533912.html',
#  'https://sfbay.craigslist.org/nby/zip/d/el-verano-free-cushions/7714703932.html',
#  'https://sfbay.craigslist.org/nby/zip/d/windsor-gas-powered-lawn-edger/7715404283.html',
#  'https://sfbay.craigslist.org/eby/zip/d/albany-box-of-shoes-mostly-size-75/7715403985.html',
#  'https://sfbay.craigslist.org/eby/zip/d/danville-free-latch-hook-rug-yarn/7715403901.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-35-floppy-diskettes/7715401628.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-bed-frame/7715401432.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-woven-jute-green/7714680123.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-employee-lockers/7715400905.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-free-six-sided-picnic-table/7715399300.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-towel-rack-a-glass-shelf/7715397180.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-large-desk-with-drawers/7707527407.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-old-iphone-docking-am-fm-radio/7715396209.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-storage-bin-for-yard-waste/7712840017.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-free-sony-bravia-32-tv/7715395017.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-tv-42-inch-panasonic-th/7715394714.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-blood-pressure-monitor-leak/7715394067.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-couch-with-pull-out-bed/7705495184.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-ikea-queen-mattress/7715394295.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hayward-softcover-and-hardcover-books/7715393947.html',
#  'https://sfbay.craigslist.org/pen/zip/d/belmont-free-chair-with-wheels/7715393112.html',
#  'https://sfbay.craigslist.org/pen/zip/d/el-granada-free-interior-wood-doors/7709864918.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-dirt-or-soil/7715390396.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/daly-city-boxes-of-various-sizes-with/7715390300.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-shelves-and-desk/7711571686.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-music-stand/7715389485.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-sony-tube-tv-nib/7715388668.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-large-mirror/7715387868.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-credenza-aka-sideboard-dresser/7713796161.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-foam-insulation-board-2-thick/7715387630.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-home-made-shabby-shelves/7709809392.html',
#  'https://sfbay.craigslist.org/eby/zip/d/pittsburg-couch-and-recliners-freeill/7714356712.html',
#  'https://sfbay.craigslist.org/pen/zip/d/menlo-park-sofas-beige-sofa-for-free/7711928339.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-guitar-shipping-boxes/7713368522.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-queen-size-bed-frame-and/7715373627.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-antique-arm-chair/7715372780.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-clay-garden-pipe/7715369693.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-pallets-for-free/7706234024.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-clean-dirt-and-delivery/7715366372.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-baby-or-dog-gate/7715366140.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-two-full-brand-new-full/7715365337.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-clay-thrower/7715365099.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-free-recliner/7715364437.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-wood-salad-bowl-and-servers/7715364328.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-floor-plastic-water-proof-sheet/7715363491.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-bbq-coal-and-plastic-container/7715360612.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-bookcase-new-in-box/7715359172.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-maytag-stacked-washer/7715358339.html',
#  'https://sfbay.craigslist.org/nby/zip/d/penngrove-cal-king-bed-with-frame/7710098837.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-two-chairs/7715354139.html',
#  'https://sfbay.craigslist.org/eby/zip/d/vallejo-wooden-window-planter-box/7711894549.html',
#  'https://sfbay.craigslist.org/scz/zip/d/santa-cruz-ikea-high-chair/7711829052.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-dvd/7715347533.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-glassware/7715347447.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-household-items/7715347381.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-queen-size-mattress-boxspring/7715343484.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-navy-leather-sofa-and-chair/7715340985.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-wood-benching-tables/7715335093.html',
#  'https://sfbay.craigslist.org/scz/zip/d/mount-hermon-curbside-alert/7715332769.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-microwave-oven-for-above/7715330009.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-ceiling-fan/7715329535.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-office-chair/7715329244.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-vessel-bathroom-sink/7715324233.html',
#  'https://sfbay.craigslist.org/pen/zip/d/burlingame-free-sectional-couch-in/7715323804.html',
#  'https://sfbay.craigslist.org/nby/zip/d/laytonville-hospital-bed/7715314438.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-tools-airless/7710482416.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-brand-new-fluourescent-light/7715308763.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-free-brown-paper-grocery-bags/7715308197.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-available-large-table-with/7711266767.html',
#  'https://sfbay.craigslist.org/scz/zip/d/morgan-hill-free-wood-chips-clean/7715306849.html',
#  'https://sfbay.craigslist.org/sby/zip/d/milpitas-free-stuu/7715306246.html',
#  'https://sfbay.craigslist.org/scz/zip/d/capitola-raft-rapid-rider/7715305986.html',
#  'https://sfbay.craigslist.org/sby/zip/d/milpitas-plywood/7715305433.html',
#  'https://sfbay.craigslist.org/scz/zip/d/aptos-free-dog-food/7715303461.html',
#  'https://sfbay.craigslist.org/sby/zip/d/milpitas-proform-treadmill/7715302679.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-moving-free-furniture/7715301148.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-ramon-black-covered-set-in-shoulder/7707906363.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-ft-shop-lamp/7709517015.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-cabinet-doors-30x-185-white/7714208964.html',
#  'https://sfbay.craigslist.org/pen/zip/d/palo-alto-disney-mcqueen-toddler-car-bed/7713196632.html',
#  'https://sfbay.craigslist.org/eby/zip/d/walnut-creek-happy-birthday-party-items/7715262342.html',
#  'https://sfbay.craigslist.org/eby/zip/d/walking-boot/7715258004.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-various-slimfast-keto-snacks/7715253895.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-queen-size-headboard/7713768502.html',
#  'https://sfbay.craigslist.org/eby/zip/d/hercules-free-rowing-machine-working/7715249756.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-free-stuffbox-of-allen/7706014251.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-scrap-wood-redwood/7715249012.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-kenmore-freezer/7715248687.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-curb-alert-california/7715247484.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-36-semi-round-mirror/7711654041.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-beautiful-quilted-queen-sized/7715247045.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-packing-materials/7715246741.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-blue-task-chair-with-wheels/7715246629.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-outdoor-dining-chairs/7715246620.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-used-sofas-set/7715245797.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-toy-organizer-shelf-with-bins/7715245134.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-free-bookshelf/7715244725.html',
#  'https://sfbay.craigslist.org/eby/zip/d/antioch-vintage-coffee-maker-desk-wine/7715241481.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-pickup-pending-free/7715243772.html',
#  'https://sfbay.craigslist.org/pen/zip/d/daly-city-fee-sectional-shaped-couch/7715243540.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-ikea-rast-drawers/7715243342.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-washer-and-dryer/7713101646.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-portable-crib-graco/7712180575.html',
#  'https://sfbay.craigslist.org/sby/zip/d/cupertino-kenmore-417-front-loading/7715241905.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-piano-music-books-from/7715241780.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-porcelain-bar-sink-1940s/7715241610.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-tie-on-seat-chair/7711916393.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-leftover-roll-of-floating/7715239412.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-drywall-purple-28x48/7715239128.html',
#  'https://sfbay.craigslist.org/eby/zip/d/danville-toilets/7707576283.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-plywood-24-34/7715238812.html']

# %% [markdown]
# Here, after parsing the requests with 'html.parser' with a soup object, we are using the BeautifulSoup's select option to find all the listing items under the class = 'cl-results-page'. On a high level, the structure will be
# **requests->class='cl-results-page'->li->(a->href)**. (a->href) is for each item in the list.
#
# Alternate method: Yes, instead of using select('a'), we can first select the 'li' under class='cl-results-page', then use the findChildren() option to select the children of 'li', and the first element in the child wil be <a> where our url will be. And subsequenty we can use this logic in a loop similar to above to identify all the listed items. The approach will follow something like "soup.select('li',class_='cl-results-page')[i].findChildren()[0].get('href')" to get the url of an item.
#
# The top 250 urls were printed based on the fact that we were able to get more than 250 listing items in our first requests to the sorted url. This method was also validated with the website by checking the top 250 items.
# We then used the select 'li' with class, and further select 'a' and get the url with 'href' for top 250 items under \<li> \</li>.
#
#
# We didn't consider the pagination feature of Craigslist to navigate through pages here. However, this can also be done. Since, from our exploration we know that there are only 120 items listed in the url, we can run the requests for each page and get the listing from top 1-120 for first two pages, and the top 1-10 for the last page. While doing this, we should also make sure to set a time.sleep() to not bombard the website with different requests in a very short time.

# %% [markdown]
# Addditional note: This part of the code (4.) was exceuted more recently than the upcoming part i.e '5. Saving HTML Pages'. Hence, there might be some differences in the above listing of  files vs the locally downloaded files, which will further be used for the Part 2. of this project.

# %% [markdown]
# ### Save HTML Pages

# %%
def save_url(urls):
    """
    Function to save URLs.
    """
    for url in urls:
        #Get the id of the listing 
        id = re.findall('.*/(.*).html',url)[0]

        #Sleep for 8 sec before sending requests
        time.sleep(8)
        url=f'{url}'
        
        headers = {'User-agent': 'Mozilla/5.0'}
        
        page = requests.get(url, headers=headers)
        soup = BeautifulSoup(page.content, 'html.parser')
        
            
        #Save them as a binary file to avoid any writing errors 
        with open(f'./urls/{id}.html', 'wb') as file:
            file.write(page.content)

#Save the URLs as individual html files for each listing 
save_url(top_250_urls)

# %% [markdown]
# <br>
# <br>

# %%
### Read Saved HTML Files

#Relative directory of all the urls
directory = "./urls" 

#Read each file and get information
for filename in os.listdir(directory):
    
    # Checking if the file ends with .html
    if filename.endswith(".html"):
        
        print(filename)
        #Constructing the full relative file path
        filepath = os.path.join(directory, filename)

        #Getting the id of the filename
        id = re.findall('./urls/(.*).html',filepath)[0]
        
        #Reading file to string
        with open(filepath, 'r', encoding='utf-8') as file:

            html = file.read()

            #Call the function to get information
            extract_information(html,id)


### 2. Extract Information

def extract_information(page,id):
    """Function to extract information from individual listing pages."""
    
    soup = BeautifulSoup(page,'html.parser')
    
    #Title of the listng 
    title = soup.select('h1',class_='postingtilte')[0].select('#titletextonly')[0].text
    
    #URL of the first image, if first image is None, returns a N/A string
    img_url = soup.find('div',class_='slide first visible').find('img').get('src') if soup.find('div',class_='slide first visible') is not None else "Not Available"
    
    #Description of the listing 
    des = soup.select_one('#postingbody').text
    des = re.findall('QR Code Link to This Post\n\n\n(.*)',des)[0]
    
    #Post id
    post_id = re.findall('.*: (.*)',soup.find('div',class_='postinginfos').select_one('p').text)[0]
    post_id
    
    #Posted Date 
    posted_date = soup.find('div',class_='postinginfos').select('p')[1].select('time')[0].get('datetime') 
    posted_date= re.findall('(\d{4}-\d{2}-\d{2})T.*',posted_date)[0]
    
    #Last Updated Date, if updated date is not available under the class postinginfos, returns a N/A information.
    last_updated_date = re.findall('(\d{4}-\d{2}-\d{2})T.*',soup.find('div',class_='postinginfos').select('p')[2].select('time')[0].get('datetime'))[0] if len(re.findall('updated',soup.find('div',class_='postinginfos').select('p')[2].text))>0 else "Date not available!"
    
    print(f"For HTML File ID: {id}\n")
    print(f"Title of the listing: {title}\n")
    print(f"The URL of the first image: {img_url}\n") if img_url is not None else print("Image not found for this url!\n")
    print(f"The description of the listing: {des}\n") 
    print(f"The Post ID: {post_id}\n")
    print(f"The posted date of the listing: {posted_date}\n")
    print(f"The last updated date of the listing: {last_updated_date}\n")
    print("\n\n")
# Out:
# 7715222808.html
# For HTML File ID: 7715222808:
#
# Title of the listing: Free 1 queen duvet insert and 6 pillows, must take all right now
#
# The URL of the first image: https://images.craigslist.org/00101_5LmfxxIj6tG_0t20CI_600x450.jpg
#
# The description of the listing: PLEASE DO NOT ASK IF AVAILABLE.
#
# The Post ID: 7715222808
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7712180575.html
# For HTML File ID: 7712180575:
#
# Title of the listing: portable crib (graco?)
#
# The URL of the first image: https://images.craigslist.org/00C0C_jdpU8Utkg0Y_0t20CI_600x450.jpg
#
# The description of the listing: portable crib
#
# The Post ID: 7712180575
#
# The posted date of the listing: 2024-01-28
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715106513.html
# For HTML File ID: 7715106513:
#
# Title of the listing: Retro TV - Good for Retro Gaming
#
# The URL of the first image: https://images.craigslist.org/00F0F_h3d0GBuVExe_0CI0t2_600x450.jpg
#
# The description of the listing: FREE
#
# The Post ID: 7715106513
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715178176.html
# For HTML File ID: 7715178176:
#
# Title of the listing: Rockwell motor and griding stone
#
# The URL of the first image: https://images.craigslist.org/00t0t_KGcHaxDhIp_0ak0dL_600x450.jpg
#
# The description of the listing: Old motor and grinding stone have not been mounted or used in years.  I do not know if they work.
#
# The Post ID: 7715178176
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715185005.html
# For HTML File ID: 7715185005:
#
# Title of the listing: China cabinet
#
# The URL of the first image: https://images.craigslist.org/00E0E_2baC3TDFwFv_0lM0CI_600x450.jpg
#
# The description of the listing: Free on the curb
#
# The Post ID: 7715185005
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715231009.html
# For HTML File ID: 7715231009:
#
# Title of the listing: FREE Windows Again
#
# The URL of the first image: https://images.craigslist.org/00y0y_1Mi0HIB85yk_0jm0ew_600x450.jpg
#
# The description of the listing: I've got more FREE windows for whomever needs them.
#
# The Post ID: 7715231009
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715134531.html
# For HTML File ID: 7715134531:
#
# Title of the listing: [FREE] Toilet (round) with soft closing lid
#
# The URL of the first image: https://images.craigslist.org/00909_it7SSPsXtZJ_0t20CI_600x450.jpg
#
# The description of the listing: [FREE] Toilet (round) with soft closing lid
#
# The Post ID: 7715134531
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715230177.html
# For HTML File ID: 7715230177:
#
# Title of the listing: Truck Top for Pickup
#
# The URL of the first image: Not Available
#
# The description of the listing: 8' Truck Top good shape fits Chevy Silverado,  FREE
#
# The Post ID: 7715230177
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715140719.html
# For HTML File ID: 7715140719:
#
# Title of the listing: Free Razer PS5 Headset
#
# The URL of the first image: https://images.craigslist.org/00j0j_5fz1sX61NHH_0ak0bl_600x450.jpg
#
# The description of the listing: Free PS5 headset for anyone in need. Don’t need it anymore as I don’t play much on the PS5
#
# The Post ID: 7715140719
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715238584.html
# For HTML File ID: 7715238584:
#
# Title of the listing: Free vintage window 36”x35”
#
# The URL of the first image: https://images.craigslist.org/00k0k_F99KzZlxzG_0t20CI_600x450.jpg
#
# The description of the listing: Salvaged from our recent basement remodel. Please email me a 2-hour time window and date when you are available for pickup. Thanks!
#
# The Post ID: 7715238584
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715246620.html
# For HTML File ID: 7715246620:
#
# Title of the listing: 4 outdoor dining chairs
#
# The URL of the first image: https://images.craigslist.org/00D0D_i0SC7PS4W4S_0CI0t2_600x450.jpg
#
# The description of the listing: Enjoy this beautiful spring weather with this set of 4 modern outdoor dining chairs. Orange plastic has faded a bit in the sun and is a bit rough in a couple spots but they are still sturdy and usable. Stackable.
#
# The Post ID: 7715246620
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7712183676.html
# For HTML File ID: 7712183676:
#
# Title of the listing: Wicker basket
#
# The URL of the first image: https://images.craigslist.org/00M0M_iLQiupON4NP_0t20CI_600x450.jpg
#
# The description of the listing: Wicker tray/shallow basket. About 13.5” across.
#
# The Post ID: 7712183676
#
# The posted date of the listing: 2024-01-28
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715249756.html
# For HTML File ID: 7715249756:
#
# Title of the listing: Free rowing machine working good
#
# The URL of the first image: https://images.craigslist.org/00I0I_chTcbpzOkgz_0i50CI_600x450.jpg
#
# The description of the listing: Slight noise when rowing everything works.
#
# The Post ID: 7715249756
#
# The posted date of the listing: 2024-02-07
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715169415.html
# For HTML File ID: 7715169415:
#
# Title of the listing: free pea gravel and 3/4" inch rocks
#
# The URL of the first image: https://images.craigslist.org/00c0c_iE4pi7o5FR1_0sV0CI_600x450.jpg
#
# The description of the listing: free pea gravel and 3/4" inch rocks
#
# The Post ID: 7715169415
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715231843.html
# For HTML File ID: 7715231843:
#
# Title of the listing: Flagpole mount for tow receiver
#
# The URL of the first image: https://images.craigslist.org/00S0S_4iTNXau2Nd1_0t20CI_600x450.jpg
#
# The description of the listing: Just in time to fly your team colors from the back of your truck! Heavy duty metal hitch mount flagpole attachment. Fits 2” receiver and allows a flagpole to be attached to the tow hitch.
#
# The Post ID: 7715231843
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715176021.html
# For HTML File ID: 7715176021:
#
# Title of the listing: Doggy supplements for joint and hip
#
# The URL of the first image: https://images.craigslist.org/00B0B_iodqAOWeAMe_0t20CI_600x450.jpg
#
# The description of the listing: Springtime brand "Advances Hip & Joint" supplements: Glucosamine, Chondroitin, MSM and Boswellia serrata in a beef liver pill. Three bottles, 60 tablets/bottle.
#
# The Post ID: 7715176021
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715205223.html
# For HTML File ID: 7715205223:
#
# Title of the listing: Three FREE Wine Cabinets
#
# The URL of the first image: https://images.craigslist.org/00i0i_br0CNhqVmEU_0CI0pM_600x450.jpg
#
# The description of the listing: In GREAT condition. Each cabinet:
#
# The Post ID: 7715205223
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715153416.html
# For HTML File ID: 7715153416:
#
# Title of the listing: WORK Bench ( San Mateo)
#
# The URL of the first image: https://images.craigslist.org/00N0N_dvmLpojliJI_0CI0t2_600x450.jpg
#
# The description of the listing: 96 inch W x 36 inch deep x 36inch H ( plus shelf).
#
# The Post ID: 7715153416
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715157140.html
# For HTML File ID: 7715157140:
#
# Title of the listing: Blue loveseat in excellent condition
#
# The URL of the first image: https://images.craigslist.org/00P0P_6e5pqbG2XSN_0CI0t2_600x450.jpg
#
# The description of the listing: We bought this about two years ago and used it very little but it does not fit into the current decorating scheme. We do have a dog and a cat so if you're allergic to such things, this would not be right for you, but it is clean and in excellent shape made by Ashley. My goal is to get it out of my garage, which is on the street level obviously. First come first served please reply with phone number
#
# The Post ID: 7715157140
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715136003.html
# For HTML File ID: 7715136003:
#
# Title of the listing: Toyota trunk lid
#
# The URL of the first image: https://images.craigslist.org/00c0c_iO4YFLkDUIV_0lM0CI_600x450.jpg
#
# The description of the listing: Free
#
# The Post ID: 7715136003
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715177333.html
# For HTML File ID: 7715177333:
#
# Title of the listing: Child Safety Locks Brand New
#
# The URL of the first image: https://images.craigslist.org/00707_e4KpkGSboUe_0t20CI_600x450.jpg
#
# The description of the listing: I bought these and never ended up using them. One of the packages has been opened but was never used. Total of 20 child safety locks for kitchen and bathroom doors and drawers.
#
# The Post ID: 7715177333
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7714117537.html
# For HTML File ID: 7714117537:
#
# Title of the listing: 32" Hollow Core Interior Door
#
# The URL of the first image: https://images.craigslist.org/00h0h_7n1c4xFWrT1_0t20CI_600x450.jpg
#
# The description of the listing: This is a 32" hollow core smooth panel interior door with jambs, hinges, and door knob latch.
#
# The Post ID: 7714117537
#
# The posted date of the listing: 2024-02-03
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7713419700.html
# For HTML File ID: 7713419700:
#
# Title of the listing: Styrofoam cooler
#
# The URL of the first image: Not Available
#
# The description of the listing: Polystyrene container for keeping hot stuff hot or cold stuff cold (but not both at the same time)
#
# The Post ID: 7713419700
#
# The posted date of the listing: 2024-02-01
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7713638556.html
# For HTML File ID: 7713638556:
#
# Title of the listing: Free Pastoral Books
#
# The URL of the first image: Not Available
#
# The description of the listing: Free Pastoral Books for Christian Evangelical Pastors (Mountain View)
#
# The Post ID: 7713638556
#
# The posted date of the listing: 2024-02-02
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715179614.html
# For HTML File ID: 7715179614:
#
# Title of the listing: Gaiam stretching ball
#
# The URL of the first image: https://images.craigslist.org/00p0p_aoznECdwUv2_0wM0CI_600x450.jpg
#
# The description of the listing: Diameter is roughly 2’
#
# The Post ID: 7715179614
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715160989.html
# For HTML File ID: 7715160989:
#
# Title of the listing: Excellent condition blue cloth loveseat
#
# The URL of the first image: https://images.craigslist.org/00808_vJgbxnUYxz_0CI0t2_600x450.jpg
#
# The description of the listing: We bought this two years ago at Ashley and barely used it. We do have a dog and a cat so if you're allergic to such things, this will not work for you. The couch is in the garage at street level
#
# The Post ID: 7715160989
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715169478.html
# For HTML File ID: 7715169478:
#
# Title of the listing: 2 LOVELY CHAIRS AND TABLE - FREE
#
# The URL of the first image: https://images.craigslist.org/00909_2fRI1QwYLnf_0t20CI_600x450.jpg
#
# The description of the listing: 2 BEAUTIFUL CHAIRS AND TABLE
#
# The Post ID: 7715169478
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7708246039.html
# For HTML File ID: 7708246039:
#
# Title of the listing: Audi wheel covers bags
#
# The URL of the first image: https://images.craigslist.org/00f0f_5X5T8vJwGxl_0t20CI_600x450.jpg
#
# The description of the listing: Audi wheel covers bags
#
# The Post ID: 7708246039
#
# The posted date of the listing: 2024-01-16
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715208169.html
# For HTML File ID: 7715208169:
#
# Title of the listing: CAT HAVEN!
#
# The URL of the first image: https://images.craigslist.org/00H0H_2XjAKtZetRC_0co0gw_600x450.jpg
#
# The description of the listing: Some of the rope might need a staple gun, but it's one of those 5' cat havens that ours never slept on, so there's no fur all over it! It's in amazing shape . . . no fooling!
#
# The Post ID: 7715208169
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715211866.html
# For HTML File ID: 7715211866:
#
# Title of the listing: Restoration Hardware sofa
#
# The URL of the first image: https://images.craigslist.org/01313_emHRe6XpNT_0Cz0t2_600x450.jpg
#
# The description of the listing: This is a very cool sofa that endured water damage. It was cleaned up at least somewhat well and used in the basement. Not sure you'd want to use it in your living room anymore. I believe it is a Restoration Hardware piece. I picked it up used as well so cannot guarantee it.
#
# The Post ID: 7715211866
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715215063.html
# For HTML File ID: 7715215063:
#
# Title of the listing: Free but stained ruggable top
#
# The URL of the first image: https://images.craigslist.org/00909_fmh00jkhGP3_0t20CI_600x450.jpg
#
# The description of the listing: This is a machine washable ruggable top that I dropped coffee in and couldn’t get out.  You can try to get out the stain or maybe hide with furniture.
#
# The Post ID: 7715215063
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7711654041.html
# For HTML File ID: 7711654041:
#
# Title of the listing: 36” semi round mirror
#
# The URL of the first image: Not Available
#
# The description of the listing: Nice semi round mirror with wood trimming. Frame have a small easily fixed crack Mirror in perfect condition. Free. Text for address.
#
# The Post ID: 7711654041
#
# The posted date of the listing: 2024-01-26
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715188928.html
# For HTML File ID: 7715188928:
#
# Title of the listing: Sit/stand desk, excellent condition
#
# The URL of the first image: https://images.craigslist.org/00E0E_7d9SgBeEkw3_0t20CI_600x450.jpg
#
# The description of the listing: White sit/stand desk measuring 31 1/2 inches wide by 63 inches long free for the taker. It raises and lowers with a simple hand crank that is quick and easy to use and snaps out of the way.
#
# The Post ID: 7715188928
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7714480447.html
# For HTML File ID: 7714480447:
#
# Title of the listing: Genuine MWF Refrigerator Water Filter for GE
#
# The URL of the first image: https://images.craigslist.org/00z0z_gIYT6DX1N8y_0oo0ww_600x450.jpg
#
# The description of the listing: See attached picture, brand new.  Pickup in Dublin.
#
# The Post ID: 7714480447
#
# The posted date of the listing: 2024-02-04
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715186126.html
# For HTML File ID: 7715186126:
#
# Title of the listing: Floor & Decor Studio Design bathroom vanity combo unit
#
# The URL of the first image: https://images.craigslist.org/00s0s_bKvCYvL1ODC_0kq0pS_600x450.jpg
#
# The description of the listing: New "open box" Floor & Decor Studio Design bathroom vanity unit. Purchased in 2019 for a home renovation project but not used (too late to return it). $400 value. Has all parts. Will help you load. Advise having a truck and helper for loading and unloading.
#
# The Post ID: 7715186126
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715244755.html
# For HTML File ID: 7715244755:
#
# Title of the listing: Magnetic Car Backseat cover for pets
#
# The URL of the first image: https://images.craigslist.org/00V0V_aPwgvf9bDSw_0t20CI_600x450.jpg
#
# The description of the listing: Giving away our magnetic car seat cover to protect your backseat from getting dirty from your pets. Not sure of exact model of car it’s meant to fit.  Could be universal
#
# The Post ID: 7715244755
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715213724.html
# For HTML File ID: 7715213724:
#
# Title of the listing: Calpico and grass jelly drinks
#
# The URL of the first image: https://images.craigslist.org/00Z0Z_de9qOMzy09u_0CI0t2_600x450.jpg
#
# The description of the listing: Both past the best by date. But this stuff will probably last until the next century if not consumed. Email or text  show contact info
#
# The Post ID: 7715213724
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715245797.html
# For HTML File ID: 7715245797:
#
# Title of the listing: Used sofas: 1 set
#
# The URL of the first image: https://images.craigslist.org/00m0m_iyq6riQ4i1Q_0CI0t2_600x450.jpg
#
# The description of the listing: In fair condition.
#
# The Post ID: 7715245797
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715149866.html
# For HTML File ID: 7715149866:
#
# Title of the listing: FREE Sofa
#
# The URL of the first image: https://images.craigslist.org/01010_jViC11uw1uU_0ww0oo_600x450.jpg
#
# The description of the listing: FREE Sofa in good condition from non-smoking non-pet home.
#
# The Post ID: 7715149866
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715234400.html
# For HTML File ID: 7715234400:
#
# Title of the listing: Electric mower
#
# The URL of the first image: https://images.craigslist.org/00l0l_k1gEngXVYq_0t20CI_600x450.jpg
#
# The description of the listing: It works! Plug in and go, it’s just got a crooked wheel so may need an adjustment. No bag. Come get before tomorrow’s trash day!
#
# The Post ID: 7715234400
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715144242.html
# For HTML File ID: 7715144242:
#
# Title of the listing: Free iclicker 2
#
# The URL of the first image: https://images.craigslist.org/00t0t_9QbTz6nB8kD_0lM0CI_600x450.jpg
#
# The description of the listing: I have 2 free iClicker 2s, I am confident at least one of the two works, not sure about the other but haven’t tested. They take AAA batteries. Used them in college, hopefully someone else can get some use out of them!
#
# The Post ID: 7715144242
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715156156.html
# For HTML File ID: 7715156156:
#
# Title of the listing: Free Wood Hutch
#
# The URL of the first image: https://images.craigslist.org/00p0p_ctRg3vFKRch_0CI0lM_600x450.jpg
#
# The description of the listing: Free for pickup on Wednesday or Thursday
#
# The Post ID: 7715156156
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7713101646.html
# For HTML File ID: 7713101646:
#
# Title of the listing: Washer and Dryer
#
# The URL of the first image: https://images.craigslist.org/00y0y_eQPWqMFKvUP_0t20CI_600x450.jpg
#
# The description of the listing: FREE washer and dryer. Need to self pickup and deliver. If interested, need to make appointment and I will send the address.
#
# The Post ID: 7713101646
#
# The posted date of the listing: 2024-01-31
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715226780.html
# For HTML File ID: 7715226780:
#
# Title of the listing: Moving out , bed tiny desk , chair
#
# The URL of the first image: https://images.craigslist.org/00z0z_hN4KpnihZ11_0CI0t2_600x450.jpg
#
# The description of the listing: Hello,
#
# The Post ID: 7715226780
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715127486.html
# For HTML File ID: 7715127486:
#
# Title of the listing: Snake plant + pot
#
# The URL of the first image: https://images.craigslist.org/00u0u_4Gr0aL5Spii_0t20CI_600x450.jpg
#
# The description of the listing: Got a snake plant that I have had for the last 4 years that seems to be slowly dying. I am not sure why and I am not enough of a green thumb to bring it back. I hope someone takes it and gives it the love it needs! Pot included.
#
# The Post ID: 7715127486
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7714031674.html
# For HTML File ID: 7714031674:
#
# Title of the listing: Tv   34 DYNEX Free
#
# The URL of the first image: Not Available
#
# The description of the listing: Its  Free. 34 in DYNEX plus can y"ou bring a remote for a lg tv if you have one          thanks
#
# The Post ID: 7714031674
#
# The posted date of the listing: 2024-02-03
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715155310.html
# For HTML File ID: 7715155310:
#
# Title of the listing: Double recliner loveseat
#
# The URL of the first image: https://images.craigslist.org/00J0J_c4CGaXNDzSQ_0CI0t9_600x450.jpg
#
# The description of the listing: Approximate dimensions:
#
# The Post ID: 7715155310
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715138315.html
# For HTML File ID: 7715138315:
#
# Title of the listing: Free kenwood turntable
#
# The URL of the first image: https://images.craigslist.org/01313_j25je0YRcyg_0hq0CI_600x450.jpg
#
# The description of the listing: This turntable is free only to a youth 18 to 21 no resellers please or anybody trying to take advantage of this. this is for someone who can't afford a turntable that wants to get into vinyl I'm over 60 I could sell it easily on eBay but that's not what I want to do I want to give it away to somebody who truly wants it and cannot afford it and I will be picky on who gets it. Turntable is ready to go comes with a diamond stylist has a new belt and fully calibrated
#
# The Post ID: 7715138315
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715171403.html
# For HTML File ID: 7715171403:
#
# Title of the listing: Dresser
#
# The URL of the first image: https://images.craigslist.org/00h0h_adVDiq8Khhs_0t20CI_600x450.jpg
#
# The description of the listing: Top drawer is a single, even though it looks like 2.  Drawers work fine.
#
# The Post ID: 7715171403
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715231073.html
# For HTML File ID: 7715231073:
#
# Title of the listing: 2 fish tanks and 1 brine shrimp hatchery.
#
# The URL of the first image: https://images.craigslist.org/00B0B_UNKOqZ2zB6_0CI0CI_600x450.jpg
#
# The description of the listing:
#
# The Post ID: 7715231073
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715149201.html
# For HTML File ID: 7715149201:
#
# Title of the listing: Free Patio Heater, Needs a bit of TLC but not bad...it's free!
#
# The URL of the first image: https://images.craigslist.org/01717_3psULE3T44K_07K0ak_600x450.jpg
#
# The description of the listing: Hello.  This is free.  The latest storm knocked over our patio heater.  It's only a year old but I'm too busy to fix it myself.  Just the top part got bent and the neck is a bit tilted.  I'm pretty sure anyone with a bit of skills could fix it.  Just needs some TLC.  I'm located in So. San Jose in 95120 zip code.  Just message me and I'll put it out for you and will give you my address.
#
# The Post ID: 7715149201
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7707012523.html
# For HTML File ID: 7707012523:
#
# Title of the listing: 26" x 28" x 3/4" clear glass
#
# The URL of the first image: Not Available
#
# The description of the listing: Table top for side or coffee table. Exc. condition. Plus 4 perfect condition clear glass shelves 36" x 4". Four other smaller pieces with a chipped corner to be removed. Include cell number and I'll text you. If you're only interested in the 3/4"x 26' x 28" piece and not removing the others, the price is $25.
#
# The Post ID: 7707012523
#
# The posted date of the listing: 2024-01-12
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715248687.html
# For HTML File ID: 7715248687:
#
# Title of the listing: Free Kenmore Freezer
#
# The URL of the first image: https://images.craigslist.org/00P0P_7jzkpdkRy2Z_0t20CI_600x450.jpg
#
# The description of the listing: Free Kenmore freezer.  It is still working good but only the door seal needs to be replaced. You need to haul it away .
#
# The Post ID: 7715248687
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715118473.html
# For HTML File ID: 7715118473:
#
# Title of the listing: Crossbody money security wallet
#
# The URL of the first image: https://images.craigslist.org/01212_8szuKa7xmI5_0lM0CI_600x450.jpg
#
# The description of the listing: Small security wallet pouch for money, passport, cards when traveling or shopping
#
# The Post ID: 7715118473
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715121159.html
# For HTML File ID: 7715121159:
#
# Title of the listing: 10” Black & Decker Chop Saw
#
# The URL of the first image: https://images.craigslist.org/00202_ed35XtRXK0C_0t20CI_600x450.jpg
#
# The description of the listing: We think it needs a new blade. Should work but might not. Electrically it should fire up. Has been outside.
#
# The Post ID: 7715121159
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715175991.html
# For HTML File ID: 7715175991:
#
# Title of the listing: ALL FREE Moving out  ( ALL OR NOTHING)
#
# The URL of the first image: https://images.craigslist.org/00A0A_5Ta5bFqq41c_07703k_600x450.jpg
#
# The description of the listing: Free for a person who could take all of these item. Please do not ask if you are not able to take them all. Thanks. If my post still here it mean the items are still available.
#
# The Post ID: 7715175991
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715118408.html
# For HTML File ID: 7715118408:
#
# Title of the listing: Tandem TSlim reservoirs
#
# The URL of the first image: Not Available
#
# The description of the listing: I have at least 4 extra boxes. Pick up only.
#
# The Post ID: 7715118408
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715141522.html
# For HTML File ID: 7715141522:
#
# Title of the listing: FREE - Chicco Car Seat, 2 docks, stroller and 2 mirrors
#
# The URL of the first image: https://images.craigslist.org/00a0a_aqnYN07iovN_0t20CI_600x450.jpg
#
# The description of the listing: Hi Mamas and Daddas!
#
# The Post ID: 7715141522
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715207593.html
# For HTML File ID: 7715207593:
#
# Title of the listing: Large all wood desk
#
# The URL of the first image: https://images.craigslist.org/00a0a_hQn2CNu0vAi_0CI0t2_600x450.jpg
#
# The description of the listing: This is a big all wood desk. It's a great desk, I have used this desk for years. It is heavy and is difficult to move, but it needs to go away since I not longer live at that address. This is why it is free.
#
# The Post ID: 7715207593
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715139894.html
# For HTML File ID: 7715139894:
#
# Title of the listing: Free kitchen cabinet doors
#
# The URL of the first image: https://images.craigslist.org/00v0v_ghrTJOYaPhN_0uk0t2_600x450.jpg
#
# The description of the listing: These doors and drawer fronts are white thermofoil covered.  Some have started to delaminate but others are fine.  Just the doors - not the cabinet boxes.  Let me know if you can use them or if you have any questions. They are still installed but we will be removing them in a few weeks.  Thanks.
#
# The Post ID: 7715139894
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715235159.html
# For HTML File ID: 7715235159:
#
# Title of the listing: Free Upper Kitchen Cabinets
#
# The URL of the first image: https://images.craigslist.org/00x0x_8ikNjpfZXmE_0t20CI_600x450.jpg
#
# The description of the listing: i just deinstalled the kitchen cabinets in the picture. uppers only. i forgot to take measurements, if interested i can get you the measurements. they're in pretty decent shape. they will be going to landfill on monday, hoping to avoid that.
#
# The Post ID: 7715235159
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7711579823.html
# For HTML File ID: 7711579823:
#
# Title of the listing: Large Sectional Couch
#
# The URL of the first image: https://images.craigslist.org/00505_fylKGJbYvq2_0CI0t2_600x450.jpg
#
# The description of the listing: Large modern sectional couch for sale.  Size is 108 x 96 we just bought a new one and it is time to give this one a final home.  Is it a good couch for a good price.   If you are looking for a large couch for a few years without worrying about young children, pets, or unsure about future living arrangement this couch is perfect.  The cushions have been replaced over the years and are nice and firm.
#
# The Post ID: 7711579823
#
# The posted date of the listing: 2024-01-26
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715201118.html
# For HTML File ID: 7715201118:
#
# Title of the listing: Free Moving Boxes
#
# The URL of the first image: Not Available
#
# The description of the listing: 14 small and medium moving boxes used once.
#
# The Post ID: 7715201118
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7706014251.html
# For HTML File ID: 7706014251:
#
# Title of the listing: Free stuff,Box of Allen wrenches
#
# The URL of the first image: https://images.craigslist.org/00404_743YITIgTy_0CI0t2_600x450.jpg
#
# The description of the listing: Free yakima bike rack no straps
#
# The Post ID: 7706014251
#
# The posted date of the listing: 2024-01-09
#
# The last updated date of the listing: 2024-02-07
#
#
#
#
# 7715232044.html
# For HTML File ID: 7715232044:
#
# Title of the listing: Power wheelchair: Invacare Pronto M51 SureStep [MELP]
#
# The URL of the first image: https://images.craigslist.org/00L0L_kAHezQ7LZaC_0CI0t2_600x450.jpg
#
# The description of the listing: Invacare Pronto M51 SureStep power chair / electric wheelchair to help with mobility indoors and outdoors.  Used, worked great, except battery is now depleted.  Battery needs to be either replaced or charged up separately from the wheelchair, not sure.  Specs: https://www.invacare.com/doc_files/02-066_M51_rev0608.pdf
#
# The Post ID: 7715232044
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7714384078.html
# For HTML File ID: 7714384078:
#
# Title of the listing: air pouch packaging
#
# The URL of the first image: https://images.craigslist.org/00e0e_hxzIc82FR3g_0lM0CI_600x450.jpg
#
# The description of the listing: Let me know when you can pick it up
#
# The Post ID: 7714384078
#
# The posted date of the listing: 2024-02-04
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715241481.html
# For HTML File ID: 7715241481:
#
# Title of the listing: Vintage Coffee Maker, Desk, Wine Rack & more!
#
# The URL of the first image: Not Available
#
# The description of the listing: Sunbeam vintage coffee maker (will throw in coffee too!)
#
# The Post ID: 7715241481
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715180020.html
# For HTML File ID: 7715180020:
#
# Title of the listing: Hat Rack
#
# The URL of the first image: https://images.craigslist.org/00I0I_efrpWFA4yrx_07K0ak_600x450.jpg
#
# The description of the listing: Stylish hat rack in good condition.  Must pick up in San Rafael.
#
# The Post ID: 7715180020
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715164165.html
# For HTML File ID: 7715164165:
#
# Title of the listing: George Foreman grill
#
# The URL of the first image: https://images.craigslist.org/00Y0Y_66VBT47XhVT_0lM0t2_600x450.jpg
#
# The description of the listing: Working George Foreman grill. In Alameda, free. Please give a pick up time.
#
# The Post ID: 7715164165
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715184389.html
# For HTML File ID: 7715184389:
#
# Title of the listing: Free  Pallets
#
# The URL of the first image: https://images.craigslist.org/00o0o_Bu3p3d92iA_0t20CI_600x450.jpg
#
# The description of the listing: Free  pallets
#
# The Post ID: 7715184389
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7711145610.html
# For HTML File ID: 7711145610:
#
# Title of the listing: FREE 1/2" "sound board"/ "bulletin board" 41" X 48"
#
# The URL of the first image: https://images.craigslist.org/00606_7CW3sYuxt3V_07K05a_600x450.jpg
#
# The description of the listing: Only costs $20 for a 4' X 8' sheet but I hate to throw it away.
#
# The Post ID: 7711145610
#
# The posted date of the listing: 2024-01-25
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715247484.html
# For HTML File ID: 7715247484:
#
# Title of the listing: Curb Alert- California & Franklin
#
# The URL of the first image: https://images.craigslist.org/00202_ij9gjWasgyB_0CI0t2_600x450.jpg
#
# The description of the listing: Microwave dishwasher and ikea shelves
#
# The Post ID: 7715247484
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715181871.html
# For HTML File ID: 7715181871:
#
# Title of the listing: Curb alert
#
# The URL of the first image: https://images.craigslist.org/00000_hxiZAKwkb6p_0lM0CI_600x450.jpg
#
# The description of the listing: Going to landfill Wednesday.  Includes an almost new king size bed frame.
#
# The Post ID: 7715181871
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715152295.html
# For HTML File ID: 7715152295:
#
# Title of the listing: White leather futon
#
# The URL of the first image: https://images.craigslist.org/00J0J_hXvmOUlwfBP_0CI0t2_600x450.jpg
#
# The description of the listing: Folds down to use as bed.  Cover used on seating area, as it is cracked
#
# The Post ID: 7715152295
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715102464.html
# For HTML File ID: 7715102464:
#
# Title of the listing: Fold and carry crate
#
# The URL of the first image: https://images.craigslist.org/00j0j_i1yl8DneutL_0lM0CI_600x450.jpg
#
# The description of the listing: Looks like it measures 2x3 feet
#
# The Post ID: 7715102464
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7714267172.html
# For HTML File ID: 7714267172:
#
# Title of the listing: FREE PAIR OF SOFAS
#
# The URL of the first image: https://images.craigslist.org/00303_51GsI5t5pSQ_0MM132_600x450.jpg
#
# The description of the listing: FREE SOFAS!! COME AND GET THEM ASAP...
#
# The Post ID: 7714267172
#
# The posted date of the listing: 2024-02-03
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715182070.html
# For HTML File ID: 7715182070:
#
# Title of the listing: *CURB ALERT* Bilstein shocks
#
# The URL of the first image: https://images.craigslist.org/00h0h_1VA6OmgcXzG_0t20CI_600x450.jpg
#
# The description of the listing: 6x auto parts car shocks. Old, garage clean out, blown probably? Scrap parts? Throttle body from 1999 BMW Z3 M Coupe. Shocks probably fit tons of things.
#
# The Post ID: 7715182070
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715123030.html
# For HTML File ID: 7715123030:
#
# Title of the listing: Free stuff in pittsburg
#
# The URL of the first image: https://images.craigslist.org/01010_eLQsJHYXFAY_0lM0CI_600x450.jpg
#
# The description of the listing: Shoes are size 8. Brand new baby food maker set and a bag full of clothes xl - 3x. Women’s. Some new some old. All in decent shape. Pick up in Pittsburg only. Will delete ad once it’s all gone! Thanks
#
# The Post ID: 7715123030
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715230167.html
# For HTML File ID: 7715230167:
#
# Title of the listing: Baby changing table
#
# The URL of the first image: https://images.craigslist.org/00n0n_25hJGRiwpxU_0CI0t2_600x450.jpg
#
# The description of the listing: This is originally a dresser changing table for my oldest daughter.
#
# The Post ID: 7715230167
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715107304.html
# For HTML File ID: 7715107304:
#
# Title of the listing: Hanging Lamp With Three Light Bulbs
#
# The URL of the first image: https://images.craigslist.org/00m0m_2WfiUyO1mLO_0lM0t2_600x450.jpg
#
# The description of the listing: Hanging Lamp With Three Light Bulbs.  Needs shades (they broke) and a chain otherwise it works fine.
#
# The Post ID: 7715107304
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715171351.html
# For HTML File ID: 7715171351:
#
# Title of the listing: FREE: 2012 Mercedes C class 30 pin cable and key fob
#
# The URL of the first image: https://images.craigslist.org/00v0v_gc9xxVpJ4px_0t20CI_600x450.jpg
#
# The description of the listing: We have two items to give away for free.   We no longer own the car so we would like to give away these accessories.
#
# The Post ID: 7715171351
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715118458.html
# For HTML File ID: 7715118458:
#
# Title of the listing: random assortment of free stuff
#
# The URL of the first image: https://images.craigslist.org/00H0H_fegDOAjxTG6_0t20CI_600x450.jpg
#
# The description of the listing: Tuesday evening update: I'm going to put everything back inside tonight at 10pm since it's supposed to start raining again tomorrow morning. Will update again when I put it back out in the next clear weather (maybe tomorrow afternoon?)
#
# The Post ID: 7715118458
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715238812.html
# For HTML File ID: 7715238812:
#
# Title of the listing: Free plywood 24” x 34”
#
# The URL of the first image: https://images.craigslist.org/01616_hvqSYpu7FjR_0t20CI_600x450.jpg
#
# The description of the listing: There’s a cut on the lower half - FYI. Please email a 2-hour time window and date(s) that you can come by for pickup. Thanks!
#
# The Post ID: 7715238812
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715244725.html
# For HTML File ID: 7715244725:
#
# Title of the listing: Free Bookshelf
#
# The URL of the first image: https://images.craigslist.org/00r0r_6Iq3u5s3mc9_0eG0t2_600x450.jpg
#
# The description of the listing: Free sturdy bookshelf! Hold a ton of stuff as you can see. 77 inches tall, 36 inches wide, 13.5 inches deep. Shelves are adjustable.
#
# The Post ID: 7715244725
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715245134.html
# For HTML File ID: 7715245134:
#
# Title of the listing: Toy Organizer Shelf with Bins
#
# The URL of the first image: https://images.craigslist.org/00M0M_i4LbgbbnAnZ_0t20t2_600x450.jpg
#
# The description of the listing: Free toy organizer with bins. Good condition, no missing parts or broken bins.
#
# The Post ID: 7715245134
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7710471918.html
# For HTML File ID: 7710471918:
#
# Title of the listing: Free Dirt
#
# The URL of the first image: https://images.craigslist.org/00E0E_kmiTzHgDnC0_0lM0t2_600x450.jpg
#
# The description of the listing: More dirt than what is shown in the picture. Must bring your own buckets or soil bags. Coordinated pick up in South Berkeley. Available until Thursday 2/8
#
# The Post ID: 7710471918
#
# The posted date of the listing: 2024-01-23
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715126418.html
# For HTML File ID: 7715126418:
#
# Title of the listing: Free bunk bed with Queen / Twin mattresses
#
# The URL of the first image: https://images.craigslist.org/00f0f_3L9h5mw4Lr0_0t20CI_600x450.jpg
#
# The description of the listing: Free bunk bed with 2 good mattresses. Must pick up by Thursday.
#
# The Post ID: 7715126418
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715180186.html
# For HTML File ID: 7715180186:
#
# Title of the listing: Wood / folding dry erase and chalkboard
#
# The URL of the first image: https://images.craigslist.org/00101_hQI5Fvu2tVr_0CI0t2_600x450.jpg
#
# The description of the listing: Good for working with your kids at the table on homework
#
# The Post ID: 7715180186
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715136418.html
# For HTML File ID: 7715136418:
#
# Title of the listing: Armchair, Good Condition, Mission Style
#
# The URL of the first image: https://images.craigslist.org/00505_b55rtV1JC1o_0t20CI_600x450.jpg
#
# The description of the listing: Free armchair, Mission-style, solid wood and olive green jacquard upholstery.  Good condition.  From a smoke- and pet-free home.  We're downsizing, otherwise would keep it.
#
# The Post ID: 7715136418
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715171310.html
# For HTML File ID: 7715171310:
#
# Title of the listing: Dresser
#
# The URL of the first image: https://images.craigslist.org/00606_dKIM1Mbhtbf_0t20CI_600x450.jpg
#
# The description of the listing: 5 drawer dresser
#
# The Post ID: 7715171310
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715209498.html
# For HTML File ID: 7715209498:
#
# Title of the listing: Chair
#
# The URL of the first image: https://images.craigslist.org/00g0g_hACCnRNPCd6_0t20CI_600x450.jpg
#
# The description of the listing: Nice chair for free.
#
# The Post ID: 7715209498
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715171804.html
# For HTML File ID: 7715171804:
#
# Title of the listing: FREE Moving Boxes and File Cabinet
#
# The URL of the first image: https://images.craigslist.org/00c0c_4EqGYWwdIUQ_0ak07K_600x450.jpg
#
# The description of the listing: FREE large Boxes for moving, and metal filing cabinet (drawers work but hard to open/close). On Twinview Dr off Grayson in Pleasant Hill.
#
# The Post ID: 7715171804
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715174169.html
# For HTML File ID: 7715174169:
#
# Title of the listing: (Found tray) Palmscale Palmscale 8 (PS8) 0.01 Accuracy
#
# The URL of the first image: Not Available
#
# The description of the listing: I recently found the large tray for the Palmscale 8 I just gave away. Since you probably won't get this, I'm giving it to whoever wants it .
#
# The Post ID: 7715174169
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715210115.html
# For HTML File ID: 7715210115:
#
# Title of the listing: Free desk
#
# The URL of the first image: https://images.craigslist.org/00E0E_754d5rm5KGJ_0t20CI_600x450.jpg
#
# The description of the listing: Free deal
#
# The Post ID: 7715210115
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7714138614.html
# For HTML File ID: 7714138614:
#
# Title of the listing: Free microwave oven
#
# The URL of the first image: https://images.craigslist.org/01010_ePo9bqnT2BT_0pO0jm_600x450.jpg
#
# The description of the listing: Control panel is showing signs of age: The number display sometimes fades, making it hard to read. The 5 button occasionally activates without being pressed, so pressing the Clear button is sometimes needed before entering a cook time. (It beeps when it activates, which might be annoying, but I imagine it could be either repaired or just put on a power strip and switched off when not in use.)
#
# The Post ID: 7714138614
#
# The posted date of the listing: 2024-02-03
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715165739.html
# For HTML File ID: 7715165739:
#
# Title of the listing: anyone know a baby CLYDE? free monogrammed stuff
#
# The URL of the first image: https://images.craigslist.org/00h0h_hKExpriEG1a_07K0ak_600x450.jpg
#
# The description of the listing: Our baby Clyde is now grown, so it is time to find a new baby Clyde who might want a rocking chair and little train set with his name on it. We also have a big boy shirt with Clyde monogrammed on the sleeve cuff. Would love to pass it on to another little Clyde!
#
# The Post ID: 7715165739
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715236709.html
# For HTML File ID: 7715236709:
#
# Title of the listing: Z Gallery Leather sectional
#
# The URL of the first image: Not Available
#
# The description of the listing: leather Z Gallery Sectional
#
# The Post ID: 7715236709
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715239412.html
# For HTML File ID: 7715239412:
#
# Title of the listing: Leftover roll of floating underlayment
#
# The URL of the first image: https://images.craigslist.org/00l0l_9aQxWYgNDnr_0t20CI_600x450.jpg
#
# The description of the listing: Purchased from Stuga flooring:
#
# The Post ID: 7715239412
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7707576283.html
# For HTML File ID: 7707576283:
#
# Title of the listing: Toilets
#
# The URL of the first image: https://images.craigslist.org/00h0h_lmb8xGI5mPG_0t20CI_600x450.jpg
#
# The description of the listing: Early 20th century toilets.
#
# The Post ID: 7707576283
#
# The posted date of the listing: 2024-01-14
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715171385.html
# For HTML File ID: 7715171385:
#
# Title of the listing: Curb alert: Desk with filing cabinet drawers
#
# The URL of the first image: https://images.craigslist.org/00u0u_NxGUHA1Lo6_0CI0t2_600x450.jpg
#
# The description of the listing: On our porch in front of 709 Almar. Come grab it! You’ll almost certainly need two people to load.
#
# The Post ID: 7715171385
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715122335.html
# For HTML File ID: 7715122335:
#
# Title of the listing: PVC pipe free
#
# The URL of the first image: https://images.craigslist.org/00202_a7DWFFUKqEW_0MM132_600x450.jpg
#
# The description of the listing: Free PVC pipe sections and 1”conduit pipe
#
# The Post ID: 7715122335
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715181153.html
# For HTML File ID: 7715181153:
#
# Title of the listing: FREE Filing Cabinet, Metal
#
# The URL of the first image: https://images.craigslist.org/00c0c_4EqGYWwdIUQ_0ak07K_600x450.jpg
#
# The description of the listing: Free black metal 2-drawer file cabinet - drawers work but hard to open/close. Also, large table box, file cabinet box and some other moving boxes if needed. Email for address and will be on curb.
#
# The Post ID: 7715181153
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715249012.html
# For HTML File ID: 7715249012:
#
# Title of the listing: scrap wood - redwood, pressure treated, etc
#
# The URL of the first image: https://images.craigslist.org/00R0R_eDxzHpQJahE_0lM0t2_600x450.jpg
#
# The description of the listing: Assorted scrap wood pieces of various sizes and shapes. Some could be good for building,  other may be useful kindling for making a fire.
#
# The Post ID: 7715249012
#
# The posted date of the listing: 2024-02-07
#
# ...
#
#
#
#
# 7715241610.html
# For HTML File ID: 7715241610:
#
# Title of the listing: Porcelain bar sink, 1940s/1950s era
#
# The URL of the first image: https://images.craigslist.org/00K0K_4aROde2JTuj_0CI0t2_600x450.jpg
#
# The description of the listing: Porcelain bar sink installed in the late 40s or early 50s. Too beautiful to head to the dump. Free if you can put it to good use!
#
# The Post ID: 7715241610
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715106398.html
# For HTML File ID: 7715106398:
#
# Title of the listing: free drumset gear (NO DRUMS)
#
# The URL of the first image: https://images.craigslist.org/00d0d_3mXUmlApw8d_0CI0lM_600x450.jpg
#
# The description of the listing: Several 3' lengths of 1 1/2" steel tubing.
#
# The Post ID: 7715106398
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7705755506.html
# For HTML File ID: 7705755506:
#
# Title of the listing: desk tops
#
# The URL of the first image: https://images.craigslist.org/00J0J_lrmbAgKZcus_0CI0t2_600x450.jpg
#
# The description of the listing: corner desk tops for projects salvage
#
# The Post ID: 7705755506
#
# The posted date of the listing: 2024-01-09
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715220928.html
# For HTML File ID: 7715220928:
#
# Title of the listing: Desk wood
#
# The URL of the first image: https://images.craigslist.org/00u0u_cAK4nyjP35C_0CI0t2_600x450.jpg
#
# The description of the listing: Small sturdy wood desk - dark brown with natural wood top and front
#
# The Post ID: 7715220928
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715139926.html
# For HTML File ID: 7715139926:
#
# Title of the listing: FREE - Mobile TV Stands w/ Adjustable Height
#
# The URL of the first image: https://images.craigslist.org/00c0c_2wDBCl8vX2s_0MM132_600x450.jpg
#
# The description of the listing: FREE two (2) mobile flat-screen TV stands with adjustable height. Has wheels for easy mobility and each wheel can be locked to keep the stand in place. Does not include TV-back mounts.
#
# The Post ID: 7715139926
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715247045.html
# For HTML File ID: 7715247045:
#
# Title of the listing: Beautiful Quilted Queen Sized Headboard
#
# The URL of the first image: https://images.craigslist.org/00M0M_7nYPcVkQWnC_0CI0t2_600x450.jpg
#
# The description of the listing: See the pic, must pic up and do so soon, will not last.
#
# The Post ID: 7715247045
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715153268.html
# For HTML File ID: 7715153268:
#
# Title of the listing: Comfortable couch with recliners on each end
#
# The URL of the first image: https://images.craigslist.org/00a0a_5WE7NEbTlPN_0CI0t2_600x450.jpg
#
# The description of the listing: The recliners both work, but the one on the right side needs adjusting.  Also could use some leather conditioner to bring back to life.  Originally from Costco
#
# The Post ID: 7715153268
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715209887.html
# For HTML File ID: 7715209887:
#
# Title of the listing: Free wood an door
#
# The URL of the first image: https://images.craigslist.org/00808_93YU9bv1vVu_0t20CI_600x450.jpg
#
# The description of the listing: Free wood and door
#
# The Post ID: 7715209887
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715166576.html
# For HTML File ID: 7715166576:
#
# Title of the listing: Ping Driver
#
# The URL of the first image: https://images.craigslist.org/00K0K_gayrPrA6nBt_0t20CI_600x450.jpg
#
# The description of the listing: Golf - Ping G-15 Driver, 10.5 degrees, regular flex
#
# The Post ID: 7715166576
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7711514664.html
# For HTML File ID: 7711514664:
#
# Title of the listing: Kids table
#
# The URL of the first image: https://images.craigslist.org/00Z0Z_6hYDknnDQVa_0CI0t2_600x450.jpg
#
# The description of the listing: Solid low table. Good for kids or a coffee or side table.
#
# The Post ID: 7711514664
#
# The posted date of the listing: 2024-01-26
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715172149.html
# For HTML File ID: 7715172149:
#
# Title of the listing: Free bathroom vanity
#
# The URL of the first image: Not Available
#
# The description of the listing:
#
# The Post ID: 7715172149
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715238476.html
# For HTML File ID: 7715238476:
#
# Title of the listing: Free plant pots, crayons, Dominoes and various other items
#
# The URL of the first image: https://images.craigslist.org/00808_8JmVQwJ2nW4_0CI0t2_600x450.jpg
#
# The description of the listing: Free items for those who want them. All cleaned and seldom used.
#
# The Post ID: 7715238476
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7713822068.html
# For HTML File ID: 7713822068:
#
# Title of the listing: Vest, Vintage
#
# The URL of the first image: https://images.craigslist.org/01111_4BOK3cgbXer_0hq0bC_600x450.jpg
#
# The description of the listing: Made in India. 100% cotton, decorated with beads and sequins on black and pink front, solid black satin back.
#
# The Post ID: 7713822068
#
# The posted date of the listing: 2024-02-02
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7714305741.html
# For HTML File ID: 7714305741:
#
# Title of the listing: kids Franklin goalie net
#
# The URL of the first image: https://images.craigslist.org/00505_8TRVvM2C1vE_0dj095_600x450.jpg
#
# The description of the listing: Kids goalie net, ready for pick up!
#
# The Post ID: 7714305741
#
# The posted date of the listing: 2024-02-04
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7705990740.html
# For HTML File ID: 7705990740:
#
# Title of the listing: Twin headboard
#
# The URL of the first image: https://images.craigslist.org/00C0C_kx8kArHTHJR_0ew0jm_600x450.jpg
#
# The description of the listing: Nice wood sturdy, twin headboard could use some refinishing, but it was in a teens room, so didn’t really matter, has lots of storage.
#
# The Post ID: 7705990740
#
# The posted date of the listing: 2024-01-09
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715243342.html
# For HTML File ID: 7715243342:
#
# Title of the listing: IKEA Rast Drawers
#
# The URL of the first image: https://images.craigslist.org/00D0D_9lEcR5cOIq_0t20CI_600x450.jpg
#
# The description of the listing: These drawers have seen better days but free to anyone who wants a DIY project. The drawers slide on plastic tracks that are broken but will hold the drawers—just needs a little caution when sliding them in and out. Wood is unfinished so could use some sanding or paint but otherwise intact and not broken.
#
# The Post ID: 7715243342
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7712177478.html
# For HTML File ID: 7712177478:
#
# Title of the listing: Free firewood
#
# The URL of the first image: https://images.craigslist.org/00202_lMsHrd2HJZG_0t20CI_600x450.jpg
#
# The description of the listing: Free redwood firewood
#
# The Post ID: 7712177478
#
# The posted date of the listing: 2024-01-28
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715160709.html
# For HTML File ID: 7715160709:
#
# Title of the listing: Free old plant nursery cart and 2 wood boxes
#
# The URL of the first image: https://images.craigslist.org/00I0I_gTP0GMNmTi9_1320AA_600x450.jpg
#
# The description of the listing: Free old plant nursery cart and 2 wood boxes.
#
# The Post ID: 7715160709
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715253895.html
# For HTML File ID: 7715253895:
#
# Title of the listing: Various Slimfast keto snacks
#
# The URL of the first image: https://images.craigslist.org/00S0S_im71w4TpewF_0g80fH_600x450.jpg
#
# The description of the listing: Got these from an event long ago but both my husband and I are kind of sick of them haha, they're very very sweet. Most of them have best by dates in January and February 2024 but I don't think they really expire...still have a few unopened boxes and 3-4 opened ones with 1 or 2 individually packaged snacks taken out of each but you can have everything!
#
# The Post ID: 7715253895
#
# The posted date of the listing: 2024-02-07
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715213622.html
# For HTML File ID: 7715213622:
#
# Title of the listing: Leather Lazyboy recliner
#
# The URL of the first image: https://images.craigslist.org/00k0k_bsqCujnNvYK_0t20CI_600x450.jpg
#
# The description of the listing: Great chair!
#
# The Post ID: 7715213622
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715189639.html
# For HTML File ID: 7715189639:
#
# Title of the listing: Logitek sit/stand heavy duty desktop and keyboard tray in excellent condition
#
# The URL of the first image: https://images.craigslist.org/01616_1NDzgUIPc1h_0t20CI_600x450.jpg
#
# The description of the listing: Logitek sit/stand heavy duty desktop and keyboard tray in excellent condition. Simple levers to lift or lower.  Has a separate keyboard, so better for ergonomics. Dimensions are in the pics.
#
# The Post ID: 7715189639
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715218330.html
# For HTML File ID: 7715218330:
#
# Title of the listing: Box of wood floor samples
#
# The URL of the first image: https://images.craigslist.org/00D0D_6kDuytWsoZ7_0lM0CI_600x450.jpg
#
# The description of the listing: Box of hardwood flooring samples, mostly oak.  Beautiful grains.
#
# The Post ID: 7715218330
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715101144.html
# For HTML File ID: 7715101144:
#
# Title of the listing: Hospital Bed
#
# The URL of the first image: Not Available
#
# The description of the listing: FREE!
#
# The Post ID: 7715101144
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715185840.html
# For HTML File ID: 7715185840:
#
# Title of the listing: Antique Danby school desk
#
# The URL of the first image: https://images.craigslist.org/01515_7GQLrJHI1q4_0tv0kS_600x450.jpg
#
# The description of the listing: Early 20th Century lift-top Danby school desk. Needs considerable restoration, but the overall structure is still sturdy. Free to a good home.
#
# The Post ID: 7715185840
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715165317.html
# For HTML File ID: 7715165317:
#
# Title of the listing: FREE IKEA FINNBY Bookcases
#
# The URL of the first image: https://images.craigslist.org/00Y0Y_8nXMNF1oY4E_0aT0ew_600x450.jpg
#
# The description of the listing: Dimensions:
#
# The Post ID: 7715165317
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715111693.html
# For HTML File ID: 7715111693:
#
# Title of the listing: Finger puppets - FREE
#
# The URL of the first image: https://images.craigslist.org/01515_pQSZq8sqVj_0CI0t2_600x450.jpg
#
# The description of the listing: Small collection of ~16 finger puppets, clean and cute. FREE.
#
# The Post ID: 7715111693
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715210741.html
# For HTML File ID: 7715210741:
#
# Title of the listing: FREE Arm's Reach co-sleeper and organic mattress
#
# The URL of the first image: https://images.craigslist.org/00g0g_jfLBCnHBkMN_1u8176_600x450.jpg
#
# The description of the listing: We have a used Arms Reach co-sleeper that is ready for a new home. We actually bought the upgraded organic mattress for it, and have an organic sheet as well. We used it for our two kids, and totted it around on vacations. It has a carrying bag that is pretty beat up as a result, but everything else is in good condition. Our kids were always good sleepers in this crib that attaches to your bed or we also used it like a pac n play. There are a few minor stains, but it is clean. If anyone wants it, it's yours!
#
# The Post ID: 7715210741
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715205056.html
# For HTML File ID: 7715205056:
#
# Title of the listing: Rustic wheelbarrow
#
# The URL of the first image: https://images.craigslist.org/00j0j_gctIYUjT6Qu_0CI0t9_600x450.jpg
#
# The description of the listing: Rustic wheelbarrow. Wheel rolls, works well for light loads. Good for light jobs around the house or for decoration.
#
# The Post ID: 7715205056
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715204811.html
# For HTML File ID: 7715204811:
#
# Title of the listing: Ivory pleather Queen bed
#
# The URL of the first image: https://images.craigslist.org/00d0d_kbqbpiqRBfe_0t20CI_600x450.jpg
#
# The description of the listing: Queen sized bed.
#
# The Post ID: 7715204811
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7711916393.html
# For HTML File ID: 7711916393:
#
# Title of the listing: Free-6 Tie-on seat / chair cushions, reversible
#
# The URL of the first image: https://images.craigslist.org/00H0H_9ISxTguNmLO_0t20CI_600x450.jpg
#
# The description of the listing: Freeee!  6 clean, lightly used Elsebet Ikea chair cushions. In good shape, reversible.
#
# The Post ID: 7711916393
#
# The posted date of the listing: 2024-01-27
#
# The last updated date of the listing: 2024-02-06
#
#
#
#
# 7715198435.html
# For HTML File ID: 7715198435:
#
# Title of the listing: Wooden pallet
#
# The URL of the first image: https://images.craigslist.org/00S0S_h0dinpXhoet_0CI0t2_600x450.jpg
#
# The description of the listing: Extra long wooden pallet. Free.
#
# The Post ID: 7715198435
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715147088.html
# For HTML File ID: 7715147088:
#
# Title of the listing: 1 two-drawer filing cabinet
#
# The URL of the first image: https://images.craigslist.org/00i0i_dOSP9jbKdpB_0lM0t2_600x450.jpg
#
# The description of the listing: Office purge. Want to keep out of the dump if we can.
#
# The Post ID: 7715147088
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715175803.html
# For HTML File ID: 7715175803:
#
# Title of the listing: Mostly free, and a few bargains
#
# The URL of the first image: https://images.craigslist.org/00808_8hVCuRg5sub_0t20CI_600x450.jpg
#
# The description of the listing: Free: One large sofa bed.  One large couch. One twin size sofabed — smaller than a love seat.  Clean, solid, no pets.  Large file cabinet for legal-sized folders, a big and sturdy bookcase, and a redwood picnic table. I have some small sets of shelves, office chairs, a hutch, dinner wear, and small tables for free, too, but you have to take a big item to take one of those.
#
# The Post ID: 7715175803
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715164087.html
# For HTML File ID: 7715164087:
#
# Title of the listing: Sealy Posturepedic Mattress Twin
#
# The URL of the first image: https://images.craigslist.org/00101_9mlEBjWoktl_0lR0t2_600x450.jpg
#
# The description of the listing: Sealy Posturepedic Twin Size Mattress
#
# The Post ID: 7715164087
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
#
#
#
#
# 7715189770.html
# For HTML File ID: 7715189770:
#
# Title of the listing: Moving out
#
# The URL of the first image: https://images.craigslist.org/00s0s_5kc2bZHRoym_0CI0t2_600x450.jpg
#
# The description of the listing: Much stuff from move out.
#
# The Post ID: 7715189770
#
# The posted date of the listing: 2024-02-06
#
# The last updated date of the listing: Date not available!
